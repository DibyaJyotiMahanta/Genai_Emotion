# %%
import google.generativeai as genai
import pathlib
import textwrap
from IPython.display import display
from IPython.display import Markdown
from google.colab import userdata
from google.colab import drive

#setting up the drive
drive.mount('/content/drive')
#get api key
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# to make the oputput turn into a Markdown text
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
#check the avaibale versions to play with.
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
#selectina a model
model = genai.GenerativeModel('gemini-pro')

# %%
#check the google Gen Ai model working
response = model.generate_content("tell me the emotions of in one word or one line'i gave up my internship with the dmrg and am feeling distraught'")
to_markdown(response.text)
# Out:
# > Devastation

# %%
#testting with a emotion dataset of kaggle but only 10 entries works as the Gemini api have a limit for 60RPM
import pandas as pd
df = pd.read_csv('text.csv')
emotions = df['text'][:10]
emotions
# Out:
# 0        i just feel really helpless and heavy hearted
# 1    ive enjoyed being able to slouch about relax a...
# 2    i gave up my internship with the dmrg and am f...
# 3                           i dont know i feel so lost
# 4    i am a kindergarten teacher and i am thoroughl...
# 5           i was beginning to feel quite disheartened
# 6    i would think that whomever would be lucky eno...
# 7    i fear that they won t ever feel that deliciou...
# 8    im forever taking some time out to have a lie ...
# 9    i can still lose the weight without feeling de...
# Name: text, dtype: object

# %%
for emotion in emotions:
  response = model.generate_content(f"tell me the emotions of '{emotion}' in one word or one line, and make it simple english")
  print(response.text)
# Out:
# Despair
# Exhausted yet refreshed
# Heartbroken
# Confusion
# Overwhelmed and anxious
# Discouraged
# Romantic
# Nostalgia
# Overwhelmed
# Empowering

# %%
text = str(input('Tell me how do You feel or anything you want to say or paste?'))
response = model.generate_content(f"tell me the emotions of {text} in one word or one line, and make it simple english")
print("Accoring to your input the emotion is:")
print('\033[1m'+f"{response.text}")
# Out:
# Tell me how do You feel or anything you want to say or paste?cooking food can be easier but it takes a lot of time
# Accoring to your input the emotion is:
# Cooking can be fun and time-consuming.
